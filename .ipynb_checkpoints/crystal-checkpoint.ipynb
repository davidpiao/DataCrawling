# %%
import requests
import pprint
import geohash2

from collections import OrderedDict

keyword = "양덕동"
url = "https://apis.zigbang.com/search?q={}".format(keyword)
req = requests.get(url)

l = []

_json = req.json()

if _json.get("code") == "200":
    data = _json.get("items")[0]
    _description = data.get("description")
    _id = data.get("id")
    _lat = data.get("lat")
    _lng = data.get("lng")
    _zoom = data.get("zoom")
    geohash = geohash2.encode(_lat, _lng, precision=5)

    url = "https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={}&rent_gteq=0&sales_type_in=전세%7C월세&service_type_eq=원룸".format(geohash)

    _req_items = requests.get(url).json()
    _items = _req_items.get("items")

    item_ids = []
    item_lat = []
    for item in _items:
        item_ids.append(item.get("item_id"))
        item_lat.append(item.get("lat"))
    # print(item_lat)

    # 위에서 저장한 list 의 100개만
    # items_ids 라는 키의 값으로 설정합니다.
    # 최종적으로 이 값을 직방 api 에 요청합니다.
    items = {"item_ids": item_ids[:3]}


    # 위에서 만든 items_ids: [매물인덱스] 를 아래 주소로 쿼리 한 후 json 형태로 받습니다.
    _results = requests.post('https://apis.zigbang.com/v2/items/list', data=items).json()

    # 최종 완성된 매물 결과는 items 안에 있습니다.
    datas = _results.get("items")

    #print(datas)
    print("@@@@@@@@@@@@@@@")
    
    # 매물 목록을 돌며 화면에 출력합니다.
    for i in range(len(datas)):
        _address = "{} {}".format(datas[i].get("address1"), datas[i].get("address2"))
        if d.get("address3") is not None:
            _address += " {}".format(datas[i].get("address3"))

        building_floor = datas[i].get("building_floor")
        floor = datas[i].get("floor")
        thumbnail = datas[i].get("images_thumbnail")
        item_id = datas[i].get("item_id")
        reg_date = datas[i].get("reg_date")
        sales_type = datas[i].get("sales_type")
        service_type = datas[i].get("service_type")
        size_m2 = datas[i].get("size_m2")
        title = datas[i].get("title")
        deposit = datas[i].get("deposit")
        rent = datas[i].get("rent")

        print("*" * 100)
        
        print("{} [{}]".format(title, item_id))
        print("보증금/월세: {}/{}".format(deposit, rent))
        print("건물층/매물층: {}/{}".format(building_floor, floor))
        print("등록일자: {}".format(reg_date))
        print("서비스형태/매물형태: {}/{}".format(service_type, sales_type))
        print("사이즈: {}".format(size_m2))

        print("****")
        atas = _results.get("items")
        #print(atas)
        
        #for a in atas:
            #id = a.get("item_id")
            #uurl = "https://apis.zigbang.com/v2/items/{}".format(id)
            #specific = {}
            #specific = requests.get(uurl).json()
            #print(specific["item"]["jibunAddress"])
        
        
        #for j in range(len(atas)):
        id = atas[i].get("item_id")
        uurl = "https://apis.zigbang.com/v2/items/{}".format(id)
        specific = []
        specific = requests.get(uurl).json()

        #print(specific)
            #temp= list(specific[0]["item"]["jibunAddress"])
            #print(specific)
        print(str(specific["item"]["jibunAddress"]))
# Out:
# @@@@@@@@@@@@@@@
# ****************************************************************************************************
# 🔵리모델링된 깔끔한 분리형원룸🔵 [30263043]
# 보증금/월세: 100/20
# 건물층/매물층: 4/2
# 등록일자: 2022-01-17T15:27:29+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 33.06
# ****
# 포항시 북구 장성동 1549-13
# ****************************************************************************************************
# ⭐⭐완전풀옵션 넓고 깔끔한방⭐⭐ [30038206]
# 보증금/월세: 200/25
# 건물층/매물층: 4/3
# 등록일자: 2022-01-10T08:22:29+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 26.45
# ****
# 포항시 북구 양덕동 1668
# ****************************************************************************************************
# ⭐엘리베이트⭐ 완전풀옵션⭐ 깔끔한 원룸⭐ [30026148]
# 보증금/월세: 200/27
# 건물층/매물층: 4/3
# 등록일자: 2022-01-01T07:29:20+09:00
# 서비스형태/매물형태: 원룸/월세
# 사이즈: 23.14
# ****
# 포항시 북구 장성동 1427-9
